# %% [markdown]
# <a href="https://colab.research.google.com/github/Shaheer04/Emotion-Recognition-BERT/blob/main/LabelEncoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing dependencies
import pandas as pd
from sklearn.preprocessing  import LabelEncoder

# %% [markdown]
# Label Encoding of Breast Cancer Dataset

# %%
# loading the dataset to pandas Dataframe
cancer_data = pd.read_csv('/content/breast-cancer.csv')

# %%
# first 5 rows
cancer_data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
cancer_data.shape
# Out:
# (569, 32)

# %%
# finding the count of different labels
cancer_data['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
# load the label encoder function
label_encode = LabelEncoder()

# %%
labels = label_encode.fit_transform(cancer_data.diagnosis)

# %%
# appending the labels to Dataframe
cancer_data['target'] = labels

# %%
cancer_data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
cancer_data['target'].value_counts()
# Out:
# 0    357
# 1    212
# Name: target, dtype: int64

# %% [markdown]
#  0 ----> B
#
#  1 ----> M

# %% [markdown]
# Label Encoding of Iris Data

# %%
# loading the dataset to pandas Dataframe
iris_data = pd.read_csv('/content/IRIS.csv')

# %%
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris_data['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
iris_label = label_encode.fit_transform(iris_data.species)

# %%
iris_data['target'] = iris_label

# %%
iris_data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species  target
# 0           5.1          3.5           1.4          0.2  Iris-setosa       0
# 1           4.9          3.0           1.4          0.2  Iris-setosa       0
# 2           4.7          3.2           1.3          0.2  Iris-setosa       0
# 3           4.6          3.1           1.5          0.2  Iris-setosa       0
# 4           5.0          3.6           1.4          0.2  Iris-setosa       0

# %%
iris_data['target'].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: target, dtype: int64
